# %% [markdown]
# # Trial Matplotlib
# - personal notes
# - based on official tutorials(https://matplotlib.org/stable/tutorials/index.html)

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### procedure 01
# - fig = plt.figure()  # an empty figure with no Axes
# - fig, ax = plt.subplots()  # a figure with a single Axes
# - fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
fig, ax = plt.subplots() # subplots() return figure and axes
ax.plot([1,2],[2,4])

# %% [markdown]
# ### Notes
# - input date to matplotlib must be "Numpy Array" (numpy.array)

# %% [markdown]
# ![formula](./images/anatomy.webp)

# %% [markdown]
# ## Two Method to draw
# - two way to use Matplotlib
#  - Method1: create Figures and Axes, and call methods on them (Object Oriented style)
#  - Method2: use pyplot and automatically create Figures and Axes, then use pyplot function for plotting

# %%
# Method 1 

x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend();  # Add a legend.

# %%
# Method 2

x = np.linspace(0, 2, 100)  # Sample data.

plt.figure(figsize=(8, 4))
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend();

# %% [markdown]
# ## Helper Function
# - to make the same plots several times, a function below is useful

# %%
def my_plotter(ax, data1, data2, param_dict):
 
    out = ax.plot(data1, data2, **param_dict)
    return out

data1, data2, data3, data4 = np.random.randn(4, 100)  # make 4 random data sets
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 2.7))
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'});

# %% [markdown]
# ## Style

# %%
fig, ax = plt.subplots(figsize=(6,4))
x = np.arange(0,10,1)
y1 = np.random.randn(10)
y2 = np.random.randn(10)
ax.plot(x,y1, color='red', linewidth=3,)
ax.plot(x,y2, color='blue', linestyle='--')

# %% [markdown]
# ## Axes labels

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax.set_xlabel('XX', fontsize=14, color='blue')
ax.set_ylabel('YY')
ax.set_title("test")
x = np.arange(0,10,1)
y = np.random.randn(10)
ax.plot(x,y)
ax.grid(True)

# %% [markdown]
# ## Annotations

# %%
fig, ax = plt.subplots(figsize=(6,4), )

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t,s)
ax.annotate('local max', xy=(2,1), xytext=(3,1.5), arrowprops=dict(facecolor='black',shrink=0.05))
ax.set_ylim(-2,2)
ax.grid(True)

# %% [markdown]
# ## Multiple Figures

# %%
fig, axd = plt.subplot_mosaic([['upleft', 'right'],
                               ['lowleft', 'right']])

axd['upleft'].set_title('upleft')
axd['lowleft'].set_title('lowleft')
axd['right'].set_title('right');


x = np.arange(0.0, np.pi*2, 0.01)
y1 = np.sin(x)
y2 = np.sin(x)
y3 = np.tan(x)

axd['upleft'].plot(x,y1)
axd['lowleft'].plot(x,y2)
axd['right'].plot(x,y3)
axd['right'].set_ylim(-10,10)

for i in axd:
    axd[i].grid()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(5.5, 3.5),
                        constrained_layout=True)
# add an artist, in this case a nice label in the middle...
for row in range(2):
    for col in range(2):
        axs[row, col].annotate(f'axs[{row}, {col}]', (0.5, 0.5),
                               transform=axs[row, col].transAxes,
                               ha='center', va='center', fontsize=18,
                               color='darkgrey')
fig.suptitle('plt.subplots()')
# Out:
# Text(0.5, 0.98, 'plt.subplots()')

# %%
def annotate_axes(ax, text, fontsize=18):
    ax.text(0.5, 0.5, text, transform=ax.transAxes,
            ha="center", va="center", fontsize=fontsize, color="darkgrey")

fig, axd = plt.subplot_mosaic([['upper left', 'upper right'],
                               ['lower left', 'lower right']],
                              figsize=(5.5, 3.5), constrained_layout=True)
for k in axd:
    annotate_axes(axd[k], f'axd["{k}"]', fontsize=14)
fig.suptitle('plt.subplot_mosaic()')
# Out:
# Text(0.5, 0.98, 'plt.subplot_mosaic()')
