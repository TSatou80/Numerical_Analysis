# %%
import matplotlib.pyplot as plt
from numpy import loadtxt
from matplotlib.pyplot import xlim

# %%
data = loadtxt("stars.txt")

# %%
plt.plot(data[:,0],data[:,1],"k.")
xlim(13000,0) #x軸を逆にした
# Out:
# (13000, 0)

# %%
plt.scatter(data[:,0],data[:,1])
