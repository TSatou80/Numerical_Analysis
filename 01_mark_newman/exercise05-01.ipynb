# %%
from numpy import loadtxt,sum, array,empty,zeros
from matplotlib.pyplot import plot

# %%
def f(x):
    return x**4 - 2*x + 1

# %%
N = 1000
a = 0.0
b = 2.0
h = (b-a)/N

# %%
s = 0.5*f(a) + 0.5*f(b)
for k in range(1,N):
    s += f(a+k*h)
print(h*s)
# Out:
# 4.400010666665601

# %%
data = loadtxt("velocities.txt")

# %%
plot(data[:,0],data[:,1])

# %%
N = data[:,0].size
a = 0.0
b = N
h = (b-a)/N

# %%
def distance(t):
    N = t
    s = 0.5*y[0] + 0.5*y[N-1]
    for k in range(1,N-1):
        s += y[int(a+k*h)]
    return h*s

# %%
x = data[:,0]
y = data[:,1]

# %%
D = zeros(x.size)
for t in range(101):
    D[t] = distance(t)

# %%
plot(x,y)
plot(x,D)
