# %%
import matplotlib.pyplot as plt
from numpy import loadtxt,array
from matplotlib.pyplot import show,xlim,imshow,colorbar,gray,jet,hot,bone,hsv

# %%
data = loadtxt("circular.txt")

# %%
data.shape
# Out:
# (501, 501)

# %%
imshow(data,origin="lower")
gray()
colorbar()
