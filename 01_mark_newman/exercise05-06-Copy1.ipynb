# %%
a = 0.0
b = 2.0
N1 = 10
N2 = 20


def f(x):
    return x**4 - 2*x + 1

# %%
def I(N):
    h = (b-a)/N
    s = (f(a) + f(b))/2
    for i in range(1,N):
        s += f(a + i*h)
    s *= h
    return s

# %%
I(N1)
# Out:
# 4.50656

# %%
I(N2)
# Out:
# 4.426660000000001

# %%
I(300)
# Out:
# 4.400118518386834

# %%
ep = (I(N2) - I(N1))/3

# %%
abs(ep)
# Out:
# 0.026633333333333137

# %%
I(10000)
# Out:
# 4.400000106666671

# %%
n = range(10,1000,10)

# %%
def ep(N):
    return (I(N*2) - I(N))/3

# %%
for i in n:
    print(abs(ep(i)))
# Out:
# 0.026633333333333137
# 0.006664583333333122
# 0.0029625514403293827
# 0.0016665364583333304
# 0.001066613333333244
# 0.0007407150205758958
# 0.0005442038039700966
# 0.00041665852864595604
# 0.00032921302646915507
# 0.0002666633333333242
# 0.00022038339821920752
# 0.0001851835776749411
# 0.00015778975992889835
# 0.00013605355407501443
# 0.00011851786008184224
# 0.00010416615804024569
# 9.22718038977403e-05
# 8.230420921684356e-05
# 7.38686269550944e-05
# 6.66664583330127e-05
# 6.0468460500118226e-05
# 5.5096276438959535e-05
# 5.040945870415925e-05
# 4.6296195827189024e-05
# 4.2666581332599186e-05
# 3.9447658812363784e-05
# 3.657972694319037e-05
# 3.401355121053958e-05
# 3.170823666091375e-05
# 2.96295884772609e-05
# 2.7748836607166538e-05
# 2.6041634877553104e-05
# 2.448726910723546e-05
# 2.306802580598344e-05
# 2.1768685270669625e-05
# 2.057611183955051e-05
# 1.9478920611900225e-05
# 1.846720469641146e-05
# 1.7532310816174384e-05
# 1.666665364593219e-05
# 1.5863561474797432e-05
# ...
