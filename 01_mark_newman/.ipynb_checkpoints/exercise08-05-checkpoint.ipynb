# %%
from math import sin, cos
from numpy import array,arange, pi
from pylab import plot, xlabel, show

# %%
g = 9.81
l = 0.1
c = 10
ohm = 2
w = 5

def f(r,t):
    theta = r[0]
    omega = r[1]
    ftheta = omega
    #fomega = -(g/l)*sin(theta) + c*cos(theta)*sin(ohm*t)
    fomega = -(g/l)*sin(theta) + c
    return array([ftheta,fomega],float)

# %%
a = 0.0
b = 10
N = 10000
h = (b-a)/N
angle = 30.0

tpoints = arange(a,b,h)
thetapoints = []
omegapoints = []

r = array([angle*2*pi/360,0],float)
for t in tpoints:
    thetapoints.append(r[0])
    omegapoints.append(r[1])
    k1 = h*f(r,t)
    k2 = h*f(r+0.5*k1, t+0.5*h)
    k3 = h*f(r+0.5*k2, t+0.5*h)
    k4 = h*f(r+k3, t+h)
    r += (k1+2*k2+2*k3+k4)/6
plot(tpoints, thetapoints)
plot(tpoints, omegapoints)
