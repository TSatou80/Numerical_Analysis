# %%
from math import pi
from numpy import linspace,array,cos,sin
#numpyのsin,cosをインポート mathではだめ。
from matplotlib.pyplot import plot

# %%
theta = linspace(0,10*pi,1000)
r = theta**2

# %%
x = r*cos(theta)
y = r*sin(theta)
#この部分で、mathのsin,cosは使えない

# %%
plot(x,y)
